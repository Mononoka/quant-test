# %%
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from typing import Dict, List, Tuple, Optional
from dataclasses import dataclass
import os
from uuid import uuid4


plt.style.use('ggplot')
sns.set_theme(style="whitegrid")

@dataclass
class MarketMaker:
    """Класс для управления стратегией маркет-мейкинга."""
    spread_bps: float = 10.0
    inventory_limit: int = 1000  
    base_position_decay: float = 0.1
    transaction_cost_bps: float = 1.0
    quote_aggressiveness: float = 2.0
    gamma: float = 0.1
    sigma: float = 0.02
    kappa: float = 1.5
    T: float = 3.0
    tick_size: float = 0.05
    volatility_window: int = 1200

    def __post_init__(self):
        self.position = 0
        self.cash = 0.0
        self.trades = []
        self.current_time = 0.0
        self.price_history = []
        self.sigma = self.sigma * np.sqrt(self.T)

    def calculate_current_volatility(self) -> float:
        """Текущая волатильность на основе последних цен."""
        if len(self.price_history) < self.volatility_window:
            return self.sigma
        prices = np.array(self.price_history[-self.volatility_window:])
        log_returns = np.diff(np.log(prices))
        if len(log_returns) == 0:
            return self.sigma
        volatility = np.std(log_returns) * np.sqrt(252)
        return max(0.001, volatility)

    def get_quotes(self, mid_price: float, market_bid: float = None, market_ask: float = None, use_benchmark: bool = False, use_dynamic_decay: bool = False) -> Tuple[float, float]:
        """Котировки bid и ask."""
        self.price_history.append(mid_price)
        inventory_skew = self.position / self.inventory_limit if self.inventory_limit > 0 else 0

        position_decay = self.base_position_decay
        if use_dynamic_decay:
            current_vol = self.calculate_current_volatility()
            position_decay = self.base_position_decay * (current_vol / self.sigma)
            position_decay = min(max(position_decay, 0.05), 0.5)

        inventory_adjustment = mid_price * (position_decay * inventory_skew / 10000)

        if use_benchmark:
            half_spread_bps = self.spread_bps / 2
            half_spread = mid_price * (half_spread_bps / 10000)
            bid_price = mid_price - half_spread - inventory_adjustment
            ask_price = mid_price + half_spread - inventory_adjustment
        else:
            q = self.position / self.inventory_limit if self.inventory_limit > 0 else 0
            time_to_expiry = self.T - self.current_time
            reservation_price = mid_price - q * self.gamma * (self.sigma ** 2) * time_to_expiry
            spread = (2 / self.gamma) * np.log(1 + (self.gamma / self.kappa))
            bid_price = reservation_price - spread / 2 - inventory_adjustment
            ask_price = reservation_price + spread / 2 - inventory_adjustment

            if market_bid is not None and market_ask is not None and self.quote_aggressiveness > 0:
                improvement = mid_price * (self.quote_aggressiveness / 10000)
                bid_price = max(bid_price, market_bid + improvement)
                ask_price = min(ask_price, market_ask - improvement)

            if market_bid is not None and market_ask is not None:
                bid_price = min(bid_price, market_ask - self.tick_size)
                ask_price = max(ask_price, market_bid + self.tick_size)

        bid_price = np.round(bid_price / self.tick_size) * self.tick_size
        ask_price = np.round(ask_price / self.tick_size) * self.tick_size
        return bid_price, ask_price

    def execute_trade(self, is_buy: bool, price: float, quantity: float, timestamp: float) -> None:
        """Исполняет сделку."""
        position_change = quantity if is_buy else -quantity
        self.position += position_change
        self.cash -= position_change * price
        transaction_cost = price * quantity * (self.transaction_cost_bps / 10000)
        self.cash -= transaction_cost
        self.trades.append({
            'timestamp': timestamp,
            'is_buy': is_buy,
            'price': price,
            'quantity': quantity,
            'position': self.position,
            'cash': self.cash
        })

    def calculate_pnl(self, mid_price: float) -> float:
        """Вычисляет текущую прибыль или убыток."""
        return self.cash + self.position * mid_price

    def update_time(self, current_time: float):
        """Обновляет текущее время в долях дня."""
        self.current_time = current_time / (24 * 3600 * 1e9)

def generate_synthetic_data(
    initial_price: float = 100.0,
    sigma: float = 0.02,
    n_steps: int = 259200,
    dt: float = 1.0 / (24 * 3600),
    spread_bps: float = 10.0
) -> pl.DataFrame:
    """Генерирует синтетические рыночные данные с заданной волатильностью."""
    np.random.seed(42)
    timestamps = np.arange(0, n_steps * 1e9, 1e9)
    mu = 0.0
    prices = np.zeros(n_steps)
    prices[0] = initial_price
    for t in range(1, n_steps):
        dW = np.random.normal(0, np.sqrt(dt))
        prices[t] = prices[t-1] * np.exp((mu - 0.5 * sigma**2) * dt + sigma * dW)
    half_spread = prices * (spread_bps / 10000) / 2
    bid_prices = prices - half_spread
    ask_prices = prices + half_spread
    return pl.DataFrame({
        'BTC-USD_timestamp': timestamps,
        'BTC-USD_bid_price_1': bid_prices,
        'BTC-USD_ask_price_1': ask_prices
    })

def run_backtest(
    df: pl.DataFrame,
    instrument_id: str,
    market_maker: MarketMaker,
    execution_prob: float = 0.2,
    latency_steps: int = 0,
    use_benchmark: bool = False,
    use_dynamic_decay: bool = False
) -> Dict:
    """Запускает бэктест стратегии."""
    if df is None or df.is_empty():
        raise ValueError("Данные отсутствуют или пусты.")
    print(f"Обработка {df.height} строк данных")
    timestamps = []
    mid_prices = []
    positions = []
    cash_balances = []
    pnls = []
    bid_quotes = []
    ask_quotes = []
    market_bids = []
    market_asks = []
    valid_rows = 0
    timestamp_col = f'{instrument_id}_timestamp'
    bid_col = f'{instrument_id}_bid_price_1'
    ask_col = f'{instrument_id}_ask_price_1'
    
    for i, row in enumerate(df.iter_rows(named=True)):
        data_idx = max(0, i - latency_steps)
        timestamp = row[timestamp_col]
        market_bid = df[data_idx, bid_col]
        market_ask = df[data_idx, ask_col]
        if np.isnan(market_bid) or np.isnan(market_ask) or market_bid <= 0 or market_ask <= 0:
            continue
        valid_rows += 1
        mid_price = (market_bid + market_ask) / 2
        market_maker.update_time(timestamp)
        bid_price, ask_price = market_maker.get_quotes(mid_price, market_bid, market_ask, use_benchmark, use_dynamic_decay)
        # Динамическая вероятность исполнения с  мягким затуханием
        bid_distance = (market_ask - bid_price) / mid_price if bid_price > 0 else 0
        ask_distance = (ask_price - market_bid) / mid_price if ask_price > 0 else 0
        bid_prob = execution_prob * np.exp(-50 * bid_distance) 
        ask_prob = execution_prob * np.exp(-50 * ask_distance)
        if bid_price > 0 and ask_price > 0:
            if np.random.random() < bid_prob:
                market_maker.execute_trade(True, bid_price, 1, timestamp)
            if np.random.random() < ask_prob:
                market_maker.execute_trade(False, ask_price, 1, timestamp)
        timestamps.append(timestamp)
        mid_prices.append(mid_price)
        positions.append(market_maker.position)
        cash_balances.append(market_maker.cash)
        pnls.append(market_maker.calculate_pnl(mid_price))
        bid_quotes.append(bid_price)
        ask_quotes.append(ask_price)
        market_bids.append(market_bid)
        market_asks.append(market_ask)
    print(f"Обработано {valid_rows} валидных строк, исполнено {len(market_maker.trades)} сделок")
    return {
        'timestamps': timestamps,
        'mid_prices': mid_prices,
        'positions': positions,
        'cash_balances': cash_balances,
        'pnls': pnls,
        'bid_quotes': bid_quotes,
        'ask_quotes': ask_quotes,
        'market_bids': market_bids,
        'market_asks': market_asks,
        'trades': market_maker.trades,
        'instrument_id': instrument_id
    }

def calculate_metrics(pnls: List[float], trades: List[Dict], mid_prices: List[float]) -> Dict:
    """Метрики."""
    pnls = np.array(pnls)
    mid_prices = np.array(mid_prices)
    
   
    if len(pnls) < 2 or np.all(pnls == 0) or np.any(np.isnan(pnls)) or len(mid_prices) < 2 or np.any(np.isnan(mid_prices)):
        print("Предупреждение: Некорректные данные PnL или mid_prices для расчёта метрик")
        return {
            'sharpe_ratio': 0.0,
            'max_drawdown': 0.0,
            'max_position': 0,
            'num_trades': len(trades)
        }

    # Расчёт относительных доходностей
    epsilon = 1e-6  
    pnl_changes = np.diff(pnls)
    avg_abs_pnl_change = np.mean(np.abs(pnl_changes))  
    returns = pnl_changes / (avg_abs_pnl_change + epsilon) 
    
    # Фильтрация выбросов
    q75, q25 = np.percentile(returns, [75, 25])
    iqr = q75 - q25
    returns = returns[(returns >= q25 - 1.5 * iqr) & (returns <= q75 + 1.5 * iqr)]
    returns = returns[~np.isnan(returns) & ~np.isinf(returns)] 
    
    mean_return = np.mean(returns) if len(returns) > 0 else 0.0
    std_return = np.std(returns) if len(returns) > 0 else 1e-6
    
    # Шарп
    if std_return > 1e-6:
        sharpe_ratio = (mean_return / std_return) * np.sqrt(252 / 3) 
    else:
        sharpe_ratio = 0.0
        print("Предупреждение: Нулевая волатильность доходности")

    #Просадки
    equity = pnls
    peak = np.maximum.accumulate(equity)
    max_abs_pnl = np.max(np.abs(pnls)) 
    drawdown = (peak - equity) / (max_abs_pnl + epsilon)  
    max_drawdown = np.max(drawdown) * 100 if np.any(drawdown > 0) else 0.0
    
   
    if max_drawdown > 100:
        print(f"Аномальная просадка: {max_drawdown:.2f}%, min_pnl={np.min(pnls):.2f}, max_pnl={np.max(pnls):.2f}")

    max_position = max(abs(trade['position']) for trade in trades) if trades else 0
    num_trades = len(trades)
    
    return {
        'sharpe_ratio': sharpe_ratio,
        'max_drawdown': max_drawdown,
        'max_position': max_position,
        'num_trades': num_trades
    }

def plot_results(results: Dict, instrument_id: str, suffix: str = '') -> None:
    """Графики результатов."""
    os.makedirs('plots', exist_ok=True)
    timestamps = pd.to_datetime(results['timestamps'], unit='ns')
    print(f"Сохранение графиков для {instrument_id}{suffix}")
    plt.figure(figsize=(12, 6))
    plt.plot(timestamps, results['mid_prices'], label='Mid Price', color='black', alpha=0.5)
    plt.plot(timestamps, results['bid_quotes'], label='Bid Quote', color='green', alpha=0.7)
    plt.plot(timestamps, results['ask_quotes'], label='Ask Quote', color='red', alpha=0.7)
    plt.plot(timestamps, results['market_bids'], label='Market Bid', color='green', alpha=0.3, linestyle='--')
    plt.plot(timestamps, results['market_asks'], label='Market Ask', color='red', alpha=0.3, linestyle='--')
    plt.title(f'Цены и котировки - {instrument_id}{suffix}')
    plt.xlabel('Время')
    plt.ylabel('Цена')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'plots/q2_{instrument_id}_quotes{suffix}.png')
    plt.close()

    plt.figure(figsize=(12, 6))
    plt.plot(timestamps, results['positions'], label='Позиция', color='blue')
    plt.title(f'Позиция - {instrument_id}{suffix}')
    plt.xlabel('Время')
    plt.ylabel('Позиция')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'plots/q2_{instrument_id}_position{suffix}.png')
    plt.close()

    plt.figure(figsize=(12, 6))
    plt.plot(timestamps, results['pnls'], label='PnL', color='green')
    plt.title(f'PnL - {instrument_id}{suffix}')
    plt.xlabel('Время')
    plt.ylabel('PnL')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'plots/q2_{instrument_id}_pnl{suffix}.png')
    plt.close()

    plt.figure(figsize=(12, 6))
    plt.plot(timestamps, results['cash_balances'], label='Кэш', color='orange')
    plt.title(f'Кэш - {instrument_id}{suffix}')
    plt.xlabel('Время')
    plt.ylabel('Кэш')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'plots/q2_{instrument_id}_cash{suffix}.png')
    plt.close()

def analyze_strategy(df: pl.DataFrame, instrument_id: str, sigma: float) -> Tuple[float, int]:
    """Анализирует стратегию с разными настройками и волатильностью."""
    latency_steps_list = [0, 5, 10, 20]
    execution_prob_list = [0.01, 0.05, 0.1]
    transaction_cost_bps_list = [0.5, 1.0, 2.0]
    tick_size_list = [0.01, 0.05, 0.1]
    volatility_scenarios = [('Low', 0.01), ('High', 0.05)]
    results_summary = []
    total_pnl = 0.0
    total_trades = 0
    base_params = {
        'spread_bps': 10.0,
        'inventory_limit': 1000,
        'base_position_decay': 0.1,
        'transaction_cost_bps': 1.0,
        'quote_aggressiveness': 2.0,
        'gamma': 0.8 if sigma == 0.05 else 0.1,  
        'sigma': sigma,
        'kappa': 1.2 if sigma == 0.05 else 1.5, 
        'T': 3.0,
        'tick_size': 0.05,
        'volatility_window': 1200
    }
    for vol_name, sigma in volatility_scenarios:
        print(f"Анализ сценария волатильности: {vol_name}, sigma={sigma}")
        df = generate_synthetic_data(sigma=sigma)
        for use_benchmark in [False, True]:
            for use_dynamic_decay in [False, True]:
                strategy_name = ('Avellaneda-Stoikov' if not use_benchmark else 'Fixed Spread Benchmark') + (' Dynamic Decay' if use_dynamic_decay else '')
                print(f"Тестирование стратегии: {strategy_name}")
                for latency_steps in latency_steps_list:
                    print(f"Тест с задержкой: {latency_steps}")
                    market_maker = MarketMaker(**base_params)
                    results = run_backtest(
                        df=df,
                        instrument_id=instrument_id,
                        market_maker=market_maker,
                        execution_prob=0.05,
                        latency_steps=latency_steps,
                        use_benchmark=use_benchmark,
                        use_dynamic_decay=use_dynamic_decay
                    )
                    final_pnl = results['pnls'][-1]
                    metrics = calculate_metrics(results['pnls'], results['trades'], results['mid_prices'])
                    print(f"Итоговый PnL: {final_pnl:.2f}, Количество сделок: {metrics['num_trades']}, Шарп: {metrics['sharpe_ratio']:.2f}, Просадка: {metrics['max_drawdown']:.2f}%")
                    total_pnl += final_pnl
                    total_trades += metrics['num_trades']
                    results_summary.append({
                        'Strategy': strategy_name,
                        'Volatility': vol_name,
                        'Factor': 'Latency',
                        'Value': latency_steps,
                        'Final PnL': final_pnl,
                        'num_trades': metrics['num_trades'],
                        'sharpe_ratio': metrics['sharpe_ratio'],
                        'max_drawdown': metrics['max_drawdown']
                    })
                    plot_results(results, instrument_id, f'_{strategy_name.replace(" ", "_")}_latency_{latency_steps}_vol_{vol_name}')
                for execution_prob in execution_prob_list:
                    print(f"Тест с вероятностью исполнения: {execution_prob}")
                    market_maker = MarketMaker(**base_params)
                    results = run_backtest(
                        df=df,
                        instrument_id=instrument_id,
                        market_maker=market_maker,
                        execution_prob=execution_prob,
                        latency_steps=0,
                        use_benchmark=use_benchmark,
                        use_dynamic_decay=use_dynamic_decay
                    )
                    final_pnl = results['pnls'][-1]
                    metrics = calculate_metrics(results['pnls'], results['trades'], results['mid_prices'])
                    print(f"Итоговый PnL: {final_pnl:.2f}, Количество сделок: {metrics['num_trades']}, Шарп: {metrics['sharpe_ratio']:.2f}, Просадка: {metrics['max_drawdown']:.2f}%")
                    total_pnl += final_pnl
                    total_trades += metrics['num_trades']
                    results_summary.append({
                        'Strategy': strategy_name,
                        'Volatility': vol_name,
                        'Factor': 'Execution Probability',
                        'Value': execution_prob,
                        'Final PnL': final_pnl,
                        'num_trades': metrics['num_trades'],
                        'sharpe_ratio': metrics['sharpe_ratio'],
                        'max_drawdown': metrics['max_drawdown']
                    })
                    plot_results(results, instrument_id, f'_{strategy_name.replace(" ", "_")}_exec_prob_{execution_prob}_vol_{vol_name}')
                for transaction_cost_bps in transaction_cost_bps_list:
                    print(f"Тест с транзакционными издержками: {transaction_cost_bps}")
                    params = base_params.copy()
                    params['transaction_cost_bps'] = transaction_cost_bps
                    market_maker = MarketMaker(**params)
                    results = run_backtest(
                        df=df,
                        instrument_id=instrument_id,
                        market_maker=market_maker,
                        execution_prob=0.05,
                        latency_steps=0,
                        use_benchmark=use_benchmark,
                        use_dynamic_decay=use_dynamic_decay
                    )
                    final_pnl = results['pnls'][-1]
                    metrics = calculate_metrics(results['pnls'], results['trades'], results['mid_prices'])
                    print(f"Итоговый PnL: {final_pnl:.2f}, Количество сделок: {metrics['num_trades']}, Шарп: {metrics['sharpe_ratio']:.2f}, Просадка: {metrics['max_drawdown']:.2f}%")
                    total_pnl += final_pnl
                    total_trades += metrics['num_trades']
                    results_summary.append({
                        'Strategy': strategy_name,
                        'Volatility': vol_name,
                        'Factor': 'Transaction Cost (bps)',
                        'Value': transaction_cost_bps,
                        'Final PnL': final_pnl,
                        'num_trades': metrics['num_trades'],
                        'sharpe_ratio': metrics['sharpe_ratio'],
                        'max_drawdown': metrics['max_drawdown']
                    })
                    plot_results(results, instrument_id, f'_{strategy_name.replace(" ", "_")}_tx_cost_{transaction_cost_bps}_vol_{vol_name}')
                for tick_size in tick_size_list:
                    print(f"Тест с размером тика: {tick_size}")
                    params = base_params.copy()
                    params['tick_size'] = tick_size
                    market_maker = MarketMaker(**params)
                    results = run_backtest(
                        df=df,
                        instrument_id=instrument_id,
                        market_maker=market_maker,
                        execution_prob=0.05,
                        latency_steps=0,
                        use_benchmark=use_benchmark,
                        use_dynamic_decay=use_dynamic_decay
                    )
                    final_pnl = results['pnls'][-1]
                    metrics = calculate_metrics(results['pnls'], results['trades'], results['mid_prices'])
                    print(f"Итоговый PnL: {final_pnl:.2f}, Количество сделок: {metrics['num_trades']}, Шарп: {metrics['sharpe_ratio']:.2f}, Просадка: {metrics['max_drawdown']:.2f}%")
                    total_pnl += final_pnl
                    total_trades += metrics['num_trades']
                    results_summary.append({
                        'Strategy': strategy_name,
                        'Volatility': vol_name,
                        'Factor': 'Tick Size',
                        'Value': tick_size,
                        'Final PnL': final_pnl,
                        'num_trades': metrics['num_trades'],
                        'sharpe_ratio': metrics['sharpe_ratio'],
                        'max_drawdown': metrics['max_drawdown']
                    })
                    plot_results(results, instrument_id, f'_{strategy_name.replace(" ", "_")}_tick_size_{tick_size}_vol_{vol_name}')

        results_df = pd.DataFrame(results_summary)
        for factor in ['Latency', 'Execution Probability', 'Transaction Cost (bps)', 'Tick Size']:
            for value in results_df[results_df['Factor'] == factor]['Value'].unique():
                subset = results_df[(results_df['Factor'] == factor) & (results_df['Value'] == value) & 
                                    (results_df['Volatility'] == vol_name)]
                print(f"\nСравнение для {factor}={value}, волатильность: {vol_name}")
                print("--------------------------------------------------")
                for _, row in subset.iterrows():
                    print(f"Стратегия: {row['Strategy']}")
                    print(f"  PnL: {row['Final PnL']:.2f}, Сделок: {row['num_trades']}, "
                          f"Шарп: {row['sharpe_ratio']:.2f}, Просадка: {row['max_drawdown']:.2f}%")
                print("--------------------------------------------------")

    print(f"Сохранение результатов анализа в plots/{instrument_id}_analysis_summary.csv")
    results_df = pd.DataFrame(results_summary)
    print(f"Результаты анализа: {len(results_df)} записей")
    print(f"Суммарный PnL для синтетических данных: {total_pnl:.2f}")
    print(f"Общее количество сделок: {total_trades}")
    results_df.to_csv(f'plots/{instrument_id}_analysis_summary.csv', index=False)

    for factor in results_df['Factor'].unique():
        for metric in ['Final PnL', 'sharpe_ratio', 'max_drawdown']:
            print(f"Создание графика: {metric} vs {factor}")
            plt.figure(figsize=(10, 6))
            sns.lineplot(data=results_df[results_df['Factor'] == factor], x='Value', y=metric, hue='Strategy', style='Volatility')
            plt.title(f'{metric} vs {factor} - {instrument_id}')
            plt.xlabel(factor)
            plt.ylabel(metric)
            plt.tight_layout()
            plt.savefig(f'plots/{instrument_id}_{metric.lower().replace(" ", "_")}_vs_{factor.lower().replace(" ", "_")}.png')
            plt.close()

    return total_pnl, total_trades

def main():
    """Запускает анализ стратегии на синтетических данных."""
    print("Запуск анализа стратегии маркет-мейкинга Авелланеда-Стоикова")
    instrument_id = 'BTC-USD'
    total_pnl_all = 0.0
    total_trades_all = 0
    print("Анализ с синтетическими данными...")
    df = generate_synthetic_data()
    synth_pnl, synth_trades = analyze_strategy(df, instrument_id, sigma=0.02)
    total_pnl_all += synth_pnl
    total_trades_all += synth_trades
    print("Анализ завершен успешно.")
    print(f"Общий суммарный PnL по всем тестам: {total_pnl_all:.2f}")
    print(f"Общее количество сделок по всем тестам: {total_trades_all}")
    return 0

if __name__ == "__main__":
    main()
# Out:
# Запуск анализа стратегии маркет-мейкинга Авелланеда-Стоикова
# Анализ с синтетическими данными...
# Анализ сценария волатильности: Low, sigma=0.01
# Тестирование стратегии: Avellaneda-Stoikov
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24777 сделок
# Итоговый PnL: 611.84, Количество сделок: 24777, Шарп: 0.09, Просадка: 15.30%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_0_vol_Low
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24745 сделок
# Итоговый PnL: 525.86, Количество сделок: 24745, Шарп: 0.15, Просадка: 9.97%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_5_vol_Low
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25237 сделок
# Итоговый PnL: 557.59, Количество сделок: 25237, Шарп: 0.24, Просадка: 6.21%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_10_vol_Low
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24933 сделок
# Итоговый PnL: 458.46, Количество сделок: 24933, Шарп: 0.08, Просадка: 32.91%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_20_vol_Low
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 4999 сделок
# Итоговый PnL: 133.55, Количество сделок: 4999, Шарп: 0.07, Просадка: 20.38%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_exec_prob_0.01_vol_Low
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24773 сделок
# Итоговый PnL: 426.46, Количество сделок: 24773, Шарп: 0.09, Просадка: 11.79%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_exec_prob_0.05_vol_Low
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 49949 сделок
# Итоговый PnL: 1103.34, Количество сделок: 49949, Шарп: 0.22, Просадка: 7.55%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_exec_prob_0.1_vol_Low
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24955 сделок
# Итоговый PnL: 755.97, Количество сделок: 24955, Шарп: 0.11, Просадка: 24.09%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tx_cost_0.5_vol_Low
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24826 сделок
# Итоговый PnL: 410.38, Количество сделок: 24826, Шарп: 0.14, Просадка: 38.24%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tx_cost_1.0_vol_Low
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24986 сделок
# Итоговый PnL: 311.07, Количество сделок: 24986, Шарп: 0.02, Просадка: 46.49%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tx_cost_2.0_vol_Low
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24862 сделок
# Итоговый PnL: 530.35, Количество сделок: 24862, Шарп: 0.28, Просадка: 8.23%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tick_size_0.01_vol_Low
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25276 сделок
# Итоговый PnL: 466.32, Количество сделок: 25276, Шарп: 0.21, Просадка: 6.37%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tick_size_0.05_vol_Low
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24640 сделок
# Итоговый PnL: 1031.13, Количество сделок: 24640, Шарп: 0.44, Просадка: 5.21%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tick_size_0.1_vol_Low
# Тестирование стратегии: Avellaneda-Stoikov Dynamic Decay
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24892 сделок
# Итоговый PnL: 563.75, Количество сделок: 24892, Шарп: 0.06, Просадка: 12.81%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_0_vol_Low
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24850 сделок
# Итоговый PnL: 504.52, Количество сделок: 24850, Шарп: 0.06, Просадка: 23.10%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_5_vol_Low
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24782 сделок
# Итоговый PnL: 380.01, Количество сделок: 24782, Шарп: 0.08, Просадка: 37.42%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_10_vol_Low
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25114 сделок
# Итоговый PnL: 550.30, Количество сделок: 25114, Шарп: 0.12, Просадка: 10.64%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_20_vol_Low
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 4984 сделок
# Итоговый PnL: 111.39, Количество сделок: 4984, Шарп: 0.03, Просадка: 39.97%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_exec_prob_0.01_vol_Low
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24876 сделок
# Итоговый PnL: 413.62, Количество сделок: 24876, Шарп: 0.11, Просадка: 12.67%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_exec_prob_0.05_vol_Low
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 49899 сделок
# Итоговый PnL: 1066.42, Количество сделок: 49899, Шарп: 0.29, Просадка: 4.61%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_exec_prob_0.1_vol_Low
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24594 сделок
# Итоговый PnL: 532.10, Количество сделок: 24594, Шарп: 0.05, Просадка: 41.98%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tx_cost_0.5_vol_Low
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24947 сделок
# Итоговый PnL: 572.79, Количество сделок: 24947, Шарп: 0.05, Просадка: 20.65%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tx_cost_1.0_vol_Low
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24801 сделок
# Итоговый PnL: 272.66, Количество сделок: 24801, Шарп: 0.01, Просадка: 71.27%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tx_cost_2.0_vol_Low
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24798 сделок
# Итоговый PnL: 445.26, Количество сделок: 24798, Шарп: 0.04, Просадка: 49.48%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tick_size_0.01_vol_Low
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25185 сделок
# Итоговый PnL: 465.45, Количество сделок: 25185, Шарп: 0.18, Просадка: 11.18%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tick_size_0.05_vol_Low
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24471 сделок
# Итоговый PnL: 803.16, Количество сделок: 24471, Шарп: 0.11, Просадка: 27.27%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tick_size_0.1_vol_Low
# Тестирование стратегии: Fixed Spread Benchmark
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24486 сделок
# Итоговый PnL: 1184.03, Количество сделок: 24486, Шарп: 0.17, Просадка: 13.04%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_0_vol_Low
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24520 сделок
# Итоговый PnL: 923.68, Количество сделок: 24520, Шарп: 0.05, Просадка: 22.74%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_5_vol_Low
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24681 сделок
# Итоговый PnL: 992.38, Количество сделок: 24681, Шарп: 0.24, Просадка: 6.35%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_10_vol_Low
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24664 сделок
# Итоговый PnL: 1185.50, Количество сделок: 24664, Шарп: 0.17, Просадка: 4.91%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_20_vol_Low
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 4996 сделок
# Итоговый PnL: 189.30, Количество сделок: 4996, Шарп: 0.19, Просадка: 8.64%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_exec_prob_0.01_vol_Low
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24499 сделок
# Итоговый PnL: 978.85, Количество сделок: 24499, Шарп: 0.11, Просадка: 9.05%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_exec_prob_0.05_vol_Low
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 48621 сделок
# Итоговый PnL: 1866.44, Количество сделок: 48621, Шарп: 0.09, Просадка: 9.46%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_exec_prob_0.1_vol_Low
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24638 сделок
# Итоговый PnL: 1196.98, Количество сделок: 24638, Шарп: 0.10, Просадка: 7.62%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tx_cost_0.5_vol_Low
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24721 сделок
# Итоговый PnL: 1008.03, Количество сделок: 24721, Шарп: 0.12, Просадка: 9.05%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tx_cost_1.0_vol_Low
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24903 сделок
# Итоговый PnL: 740.54, Количество сделок: 24903, Шарп: 0.08, Просадка: 21.40%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tx_cost_2.0_vol_Low
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24722 сделок
# Итоговый PnL: 913.90, Количество сделок: 24722, Шарп: 0.32, Просадка: 2.48%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tick_size_0.01_vol_Low
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24791 сделок
# Итоговый PnL: 1007.23, Количество сделок: 24791, Шарп: 0.21, Просадка: 9.58%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tick_size_0.05_vol_Low
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24244 сделок
# Итоговый PnL: 992.26, Количество сделок: 24244, Шарп: 0.25, Просадка: 4.13%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tick_size_0.1_vol_Low
# Тестирование стратегии: Fixed Spread Benchmark Dynamic Decay
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24787 сделок
# Итоговый PnL: 816.03, Количество сделок: 24787, Шарп: 0.08, Просадка: 34.00%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_0_vol_Low
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24808 сделок
# Итоговый PnL: 980.45, Количество сделок: 24808, Шарп: 0.12, Просадка: 9.40%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_5_vol_Low
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24569 сделок
# Итоговый PnL: 925.12, Количество сделок: 24569, Шарп: 0.09, Просадка: 22.29%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_10_vol_Low
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24419 сделок
# Итоговый PnL: 938.62, Количество сделок: 24419, Шарп: 0.06, Просадка: 20.30%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_20_vol_Low
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 4972 сделок
# Итоговый PnL: 189.30, Количество сделок: 4972, Шарп: 0.11, Просадка: 11.04%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_exec_prob_0.01_vol_Low
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24729 сделок
# Итоговый PnL: 962.51, Количество сделок: 24729, Шарп: 0.09, Просадка: 10.27%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_exec_prob_0.05_vol_Low
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 48982 сделок
# Итоговый PnL: 1958.22, Количество сделок: 48982, Шарп: 0.89, Просадка: 1.59%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_exec_prob_0.1_vol_Low
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24648 сделок
# Итоговый PnL: 1080.58, Количество сделок: 24648, Шарп: 0.27, Просадка: 3.47%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tx_cost_0.5_vol_Low
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24721 сделок
# Итоговый PnL: 1035.01, Количество сделок: 24721, Шарп: 0.10, Просадка: 12.00%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tx_cost_1.0_vol_Low
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24882 сделок
# Итоговый PnL: 720.62, Количество сделок: 24882, Шарп: 0.08, Просадка: 22.13%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tx_cost_2.0_vol_Low
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24400 сделок
# Итоговый PnL: 898.05, Количество сделок: 24400, Шарп: 0.25, Просадка: 5.08%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tick_size_0.01_vol_Low
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24685 сделок
# Итоговый PnL: 1039.40, Количество сделок: 24685, Шарп: 0.28, Просадка: 8.34%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tick_size_0.05_vol_Low
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25013 сделок
# Итоговый PnL: 993.04, Количество сделок: 25013, Шарп: 0.09, Просадка: 13.63%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tick_size_0.1_vol_Low
#
# Сравнение для Latency=0.0, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 611.84, Сделок: 24777, Шарп: 0.09, Просадка: 15.30%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 563.75, Сделок: 24892, Шарп: 0.06, Просадка: 12.81%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1184.03, Сделок: 24486, Шарп: 0.17, Просадка: 13.04%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 816.03, Сделок: 24787, Шарп: 0.08, Просадка: 34.00%
# --------------------------------------------------
#
# Сравнение для Latency=5.0, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 525.86, Сделок: 24745, Шарп: 0.15, Просадка: 9.97%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 504.52, Сделок: 24850, Шарп: 0.06, Просадка: 23.10%
# Стратегия: Fixed Spread Benchmark
#   PnL: 923.68, Сделок: 24520, Шарп: 0.05, Просадка: 22.74%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 980.45, Сделок: 24808, Шарп: 0.12, Просадка: 9.40%
# --------------------------------------------------
#
# Сравнение для Latency=10.0, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 557.59, Сделок: 25237, Шарп: 0.24, Просадка: 6.21%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 380.01, Сделок: 24782, Шарп: 0.08, Просадка: 37.42%
# Стратегия: Fixed Spread Benchmark
#   PnL: 992.38, Сделок: 24681, Шарп: 0.24, Просадка: 6.35%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 925.12, Сделок: 24569, Шарп: 0.09, Просадка: 22.29%
# --------------------------------------------------
#
# Сравнение для Latency=20.0, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 458.46, Сделок: 24933, Шарп: 0.08, Просадка: 32.91%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 550.30, Сделок: 25114, Шарп: 0.12, Просадка: 10.64%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1185.50, Сделок: 24664, Шарп: 0.17, Просадка: 4.91%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 938.62, Сделок: 24419, Шарп: 0.06, Просадка: 20.30%
# --------------------------------------------------
#
# Сравнение для Execution Probability=0.01, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 133.55, Сделок: 4999, Шарп: 0.07, Просадка: 20.38%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 111.39, Сделок: 4984, Шарп: 0.03, Просадка: 39.97%
# Стратегия: Fixed Spread Benchmark
#   PnL: 189.30, Сделок: 4996, Шарп: 0.19, Просадка: 8.64%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 189.30, Сделок: 4972, Шарп: 0.11, Просадка: 11.04%
# --------------------------------------------------
#
# Сравнение для Execution Probability=0.05, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 426.46, Сделок: 24773, Шарп: 0.09, Просадка: 11.79%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 413.62, Сделок: 24876, Шарп: 0.11, Просадка: 12.67%
# Стратегия: Fixed Spread Benchmark
#   PnL: 978.85, Сделок: 24499, Шарп: 0.11, Просадка: 9.05%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 962.51, Сделок: 24729, Шарп: 0.09, Просадка: 10.27%
# --------------------------------------------------
#
# Сравнение для Execution Probability=0.1, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 1103.34, Сделок: 49949, Шарп: 0.22, Просадка: 7.55%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 1066.42, Сделок: 49899, Шарп: 0.29, Просадка: 4.61%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1866.44, Сделок: 48621, Шарп: 0.09, Просадка: 9.46%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1958.22, Сделок: 48982, Шарп: 0.89, Просадка: 1.59%
# --------------------------------------------------
#
# Сравнение для Transaction Cost (bps)=0.5, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 755.97, Сделок: 24955, Шарп: 0.11, Просадка: 24.09%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 532.10, Сделок: 24594, Шарп: 0.05, Просадка: 41.98%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1196.98, Сделок: 24638, Шарп: 0.10, Просадка: 7.62%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1080.58, Сделок: 24648, Шарп: 0.27, Просадка: 3.47%
# --------------------------------------------------
#
# Сравнение для Transaction Cost (bps)=1.0, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 410.38, Сделок: 24826, Шарп: 0.14, Просадка: 38.24%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 572.79, Сделок: 24947, Шарп: 0.05, Просадка: 20.65%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1008.03, Сделок: 24721, Шарп: 0.12, Просадка: 9.05%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1035.01, Сделок: 24721, Шарп: 0.10, Просадка: 12.00%
# --------------------------------------------------
#
# Сравнение для Transaction Cost (bps)=2.0, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 311.07, Сделок: 24986, Шарп: 0.02, Просадка: 46.49%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 272.66, Сделок: 24801, Шарп: 0.01, Просадка: 71.27%
# Стратегия: Fixed Spread Benchmark
#   PnL: 740.54, Сделок: 24903, Шарп: 0.08, Просадка: 21.40%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 720.62, Сделок: 24882, Шарп: 0.08, Просадка: 22.13%
# --------------------------------------------------
#
# Сравнение для Tick Size=0.01, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 530.35, Сделок: 24862, Шарп: 0.28, Просадка: 8.23%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 445.26, Сделок: 24798, Шарп: 0.04, Просадка: 49.48%
# Стратегия: Fixed Spread Benchmark
#   PnL: 913.90, Сделок: 24722, Шарп: 0.32, Просадка: 2.48%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 898.05, Сделок: 24400, Шарп: 0.25, Просадка: 5.08%
# --------------------------------------------------
#
# Сравнение для Tick Size=0.05, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 466.32, Сделок: 25276, Шарп: 0.21, Просадка: 6.37%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 465.45, Сделок: 25185, Шарп: 0.18, Просадка: 11.18%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1007.23, Сделок: 24791, Шарп: 0.21, Просадка: 9.58%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1039.40, Сделок: 24685, Шарп: 0.28, Просадка: 8.34%
# --------------------------------------------------
#
# Сравнение для Tick Size=0.1, волатильность: Low
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 1031.13, Сделок: 24640, Шарп: 0.44, Просадка: 5.21%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 803.16, Сделок: 24471, Шарп: 0.11, Просадка: 27.27%
# Стратегия: Fixed Spread Benchmark
#   PnL: 992.26, Сделок: 24244, Шарп: 0.25, Просадка: 4.13%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 993.04, Сделок: 25013, Шарп: 0.09, Просадка: 13.63%
# --------------------------------------------------
# Анализ сценария волатильности: High, sigma=0.05
# Тестирование стратегии: Avellaneda-Stoikov
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24781 сделок
# Итоговый PnL: 1114.93, Количество сделок: 24781, Шарп: 0.02, Просадка: 49.79%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_0_vol_High
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24737 сделок
# Итоговый PnL: 717.53, Количество сделок: 24737, Шарп: 0.07, Просадка: 55.37%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_5_vol_High
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25235 сделок
# Итоговый PnL: 785.21, Количество сделок: 25235, Шарп: 0.04, Просадка: 27.53%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_10_vol_High
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24956 сделок
# Итоговый PnL: 251.46, Количество сделок: 24956, Шарп: 0.02, Просадка: 92.77%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_latency_20_vol_High
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 5005 сделок
# Итоговый PnL: 289.58, Количество сделок: 5005, Шарп: 0.01, Просадка: 57.86%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_exec_prob_0.01_vol_High
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24760 сделок
# Итоговый PnL: 166.47, Количество сделок: 24760, Шарп: 0.00, Просадка: 79.65%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_exec_prob_0.05_vol_High
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 49960 сделок
# Итоговый PnL: 1555.40, Количество сделок: 49960, Шарп: 0.06, Просадка: 31.81%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_exec_prob_0.1_vol_High
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24924 сделок
# Итоговый PnL: 1334.54, Количество сделок: 24924, Шарп: 0.03, Просадка: 74.79%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tx_cost_0.5_vol_High
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24817 сделок
# Аномальная просадка: 107.33%, min_pnl=-77.52, max_pnl=1058.03
# Итоговый PnL: 105.67, Количество сделок: 24817, Шарп: 0.03, Просадка: 107.33%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tx_cost_1.0_vol_High
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25003 сделок
# Аномальная просадка: 118.44%, min_pnl=-517.51, max_pnl=786.20
# Итоговый PnL: 635.65, Количество сделок: 25003, Шарп: 0.01, Просадка: 118.44%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tx_cost_2.0_vol_High
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24871 сделок
# Итоговый PnL: 701.13, Количество сделок: 24871, Шарп: 0.09, Просадка: 32.66%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tick_size_0.01_vol_High
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25281 сделок
# Итоговый PnL: 323.46, Количество сделок: 25281, Шарп: 0.01, Просадка: 40.38%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tick_size_0.05_vol_High
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24666 сделок
# Итоговый PnL: 1238.01, Количество сделок: 24666, Шарп: 0.08, Просадка: 33.00%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_tick_size_0.1_vol_High
# Тестирование стратегии: Avellaneda-Stoikov Dynamic Decay
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24897 сделок
# Итоговый PnL: 798.98, Количество сделок: 24897, Шарп: 0.02, Просадка: 44.75%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_0_vol_High
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24849 сделок
# Итоговый PnL: 532.83, Количество сделок: 24849, Шарп: 0.01, Просадка: 69.65%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_5_vol_High
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24787 сделок
# Аномальная просадка: 137.47%, min_pnl=-333.14, max_pnl=889.06
# Итоговый PnL: -155.62, Количество сделок: 24787, Шарп: 0.02, Просадка: 137.47%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_10_vol_High
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25118 сделок
# Итоговый PnL: 782.87, Количество сделок: 25118, Шарп: 0.04, Просадка: 40.35%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_latency_20_vol_High
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 4973 сделок
# Итоговый PnL: 150.07, Количество сделок: 4973, Шарп: 0.01, Просадка: 82.21%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_exec_prob_0.01_vol_High
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24878 сделок
# Аномальная просадка: 175.85%, min_pnl=-161.44, max_pnl=212.83
# Итоговый PnL: 85.19, Количество сделок: 24878, Шарп: -0.01, Просадка: 175.85%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_exec_prob_0.05_vol_High
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 49860 сделок
# Итоговый PnL: 1296.15, Количество сделок: 49860, Шарп: 0.05, Просадка: 29.07%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_exec_prob_0.1_vol_High
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24575 сделок
# Аномальная просадка: 110.90%, min_pnl=-374.31, max_pnl=1817.48
# Итоговый PnL: 109.55, Количество сделок: 24575, Шарп: 0.02, Просадка: 110.90%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tx_cost_0.5_vol_High
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24928 сделок
# Итоговый PnL: 874.76, Количество сделок: 24928, Шарп: 0.02, Просадка: 50.34%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tx_cost_1.0_vol_High
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24778 сделок
# Аномальная просадка: 149.14%, min_pnl=-1031.34, max_pnl=560.51
# Итоговый PnL: 403.04, Количество сделок: 24778, Шарп: -0.00, Просадка: 149.14%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tx_cost_2.0_vol_High
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24787 сделок
# Аномальная просадка: 110.82%, min_pnl=-386.37, max_pnl=1631.81
# Итоговый PnL: 197.40, Количество сделок: 24787, Шарп: 0.02, Просадка: 110.82%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tick_size_0.01_vol_High
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 25205 сделок
# Итоговый PnL: 374.62, Количество сделок: 25205, Шарп: 0.02, Просадка: 58.01%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tick_size_0.05_vol_High
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24457 сделок
# Аномальная просадка: 113.57%, min_pnl=-213.90, max_pnl=1576.12
# Итоговый PnL: 34.36, Количество сделок: 24457, Шарп: 0.03, Просадка: 113.57%
# Сохранение графиков для BTC-USD_Avellaneda-Stoikov_Dynamic_Decay_tick_size_0.1_vol_High
# Тестирование стратегии: Fixed Spread Benchmark
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24474 сделок
# Итоговый PnL: 2016.76, Количество сделок: 24474, Шарп: 0.05, Просадка: 47.85%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_0_vol_High
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24503 сделок
# Итоговый PnL: 621.26, Количество сделок: 24503, Шарп: 0.01, Просадка: 82.44%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_5_vol_High
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24694 сделок
# Итоговый PnL: 1111.37, Количество сделок: 24694, Шарп: 0.02, Просадка: 46.23%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_10_vol_High
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24670 сделок
# Итоговый PnL: 1983.23, Количество сделок: 24670, Шарп: 0.03, Просадка: 25.39%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_latency_20_vol_High
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 5001 сделок
# Итоговый PnL: 137.07, Количество сделок: 5001, Шарп: 0.05, Просадка: 55.57%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_exec_prob_0.01_vol_High
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24488 сделок
# Итоговый PnL: 1024.57, Количество сделок: 24488, Шарп: 0.02, Просадка: 60.09%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_exec_prob_0.05_vol_High
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 48635 сделок
# Итоговый PnL: 1595.48, Количество сделок: 48635, Шарп: 0.02, Просадка: 85.58%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_exec_prob_0.1_vol_High
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24651 сделок
# Итоговый PnL: 1546.44, Количество сделок: 24651, Шарп: 0.03, Просадка: 42.67%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tx_cost_0.5_vol_High
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24732 сделок
# Итоговый PnL: 1026.21, Количество сделок: 24732, Шарп: 0.04, Просадка: 46.04%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tx_cost_1.0_vol_High
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24890 сделок
# Итоговый PnL: 753.73, Количество сделок: 24890, Шарп: 0.02, Просадка: 64.00%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tx_cost_2.0_vol_High
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24734 сделок
# Итоговый PnL: 603.19, Количество сделок: 24734, Шарп: 0.05, Просадка: 28.75%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tick_size_0.01_vol_High
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24756 сделок
# Итоговый PnL: 1097.64, Количество сделок: 24756, Шарп: 0.05, Просадка: 63.37%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tick_size_0.05_vol_High
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24234 сделок
# Итоговый PnL: 957.16, Количество сделок: 24234, Шарп: 0.06, Просадка: 31.92%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_tick_size_0.1_vol_High
# Тестирование стратегии: Fixed Spread Benchmark Dynamic Decay
# Тест с задержкой: 0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24802 сделок
# Аномальная просадка: 117.39%, min_pnl=-331.05, max_pnl=1903.17
# Итоговый PnL: 15.99, Количество сделок: 24802, Шарп: 0.02, Просадка: 117.39%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_0_vol_High
# Тест с задержкой: 5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24803 сделок
# Итоговый PnL: 981.54, Количество сделок: 24803, Шарп: 0.02, Просадка: 72.37%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_5_vol_High
# Тест с задержкой: 10
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24558 сделок
# Итоговый PnL: 601.06, Количество сделок: 24558, Шарп: 0.02, Просадка: 84.93%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_10_vol_High
# Тест с задержкой: 20
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24424 сделок
# Итоговый PnL: 739.51, Количество сделок: 24424, Шарп: 0.01, Просадка: 74.05%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_latency_20_vol_High
# Тест с вероятностью исполнения: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 4973 сделок
# Итоговый PnL: 104.00, Количество сделок: 4973, Шарп: 0.02, Просадка: 83.52%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_exec_prob_0.01_vol_High
# Тест с вероятностью исполнения: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24729 сделок
# Итоговый PnL: 867.73, Количество сделок: 24729, Шарп: 0.03, Просадка: 47.34%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_exec_prob_0.05_vol_High
# Тест с вероятностью исполнения: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 48989 сделок
# Итоговый PnL: 1933.54, Количество сделок: 48989, Шарп: 0.17, Просадка: 13.66%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_exec_prob_0.1_vol_High
# Тест с транзакционными издержками: 0.5
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24640 сделок
# Итоговый PnL: 963.12, Количество сделок: 24640, Шарп: 0.05, Просадка: 27.13%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tx_cost_0.5_vol_High
# Тест с транзакционными издержками: 1.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24742 сделок
# Итоговый PnL: 1257.21, Количество сделок: 24742, Шарп: 0.02, Просадка: 69.50%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tx_cost_1.0_vol_High
# Тест с транзакционными издержками: 2.0
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24874 сделок
# Итоговый PnL: 558.23, Количество сделок: 24874, Шарп: 0.02, Просадка: 75.12%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tx_cost_2.0_vol_High
# Тест с размером тика: 0.01
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24409 сделок
# Итоговый PnL: 601.59, Количество сделок: 24409, Шарп: 0.02, Просадка: 64.78%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tick_size_0.01_vol_High
# Тест с размером тика: 0.05
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24680 сделок
# Итоговый PnL: 1265.32, Количество сделок: 24680, Шарп: 0.06, Просадка: 51.10%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tick_size_0.05_vol_High
# Тест с размером тика: 0.1
# Обработка 259200 строк данных
# Обработано 259200 валидных строк, исполнено 24991 сделок
# Итоговый PnL: 983.13, Количество сделок: 24991, Шарп: 0.02, Просадка: 54.60%
# Сохранение графиков для BTC-USD_Fixed_Spread_Benchmark_Dynamic_Decay_tick_size_0.1_vol_High
#
# Сравнение для Latency=0.0, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 1114.93, Сделок: 24781, Шарп: 0.02, Просадка: 49.79%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 798.98, Сделок: 24897, Шарп: 0.02, Просадка: 44.75%
# Стратегия: Fixed Spread Benchmark
#   PnL: 2016.76, Сделок: 24474, Шарп: 0.05, Просадка: 47.85%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 15.99, Сделок: 24802, Шарп: 0.02, Просадка: 117.39%
# --------------------------------------------------
#
# Сравнение для Latency=5.0, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 717.53, Сделок: 24737, Шарп: 0.07, Просадка: 55.37%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 532.83, Сделок: 24849, Шарп: 0.01, Просадка: 69.65%
# Стратегия: Fixed Spread Benchmark
#   PnL: 621.26, Сделок: 24503, Шарп: 0.01, Просадка: 82.44%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 981.54, Сделок: 24803, Шарп: 0.02, Просадка: 72.37%
# --------------------------------------------------
#
# Сравнение для Latency=10.0, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 785.21, Сделок: 25235, Шарп: 0.04, Просадка: 27.53%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: -155.62, Сделок: 24787, Шарп: 0.02, Просадка: 137.47%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1111.37, Сделок: 24694, Шарп: 0.02, Просадка: 46.23%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 601.06, Сделок: 24558, Шарп: 0.02, Просадка: 84.93%
# --------------------------------------------------
#
# Сравнение для Latency=20.0, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 251.46, Сделок: 24956, Шарп: 0.02, Просадка: 92.77%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 782.87, Сделок: 25118, Шарп: 0.04, Просадка: 40.35%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1983.23, Сделок: 24670, Шарп: 0.03, Просадка: 25.39%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 739.51, Сделок: 24424, Шарп: 0.01, Просадка: 74.05%
# --------------------------------------------------
#
# Сравнение для Execution Probability=0.01, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 289.58, Сделок: 5005, Шарп: 0.01, Просадка: 57.86%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 150.07, Сделок: 4973, Шарп: 0.01, Просадка: 82.21%
# Стратегия: Fixed Spread Benchmark
#   PnL: 137.07, Сделок: 5001, Шарп: 0.05, Просадка: 55.57%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 104.00, Сделок: 4973, Шарп: 0.02, Просадка: 83.52%
# --------------------------------------------------
#
# Сравнение для Execution Probability=0.05, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 166.47, Сделок: 24760, Шарп: 0.00, Просадка: 79.65%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 85.19, Сделок: 24878, Шарп: -0.01, Просадка: 175.85%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1024.57, Сделок: 24488, Шарп: 0.02, Просадка: 60.09%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 867.73, Сделок: 24729, Шарп: 0.03, Просадка: 47.34%
# --------------------------------------------------
#
# Сравнение для Execution Probability=0.1, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 1555.40, Сделок: 49960, Шарп: 0.06, Просадка: 31.81%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 1296.15, Сделок: 49860, Шарп: 0.05, Просадка: 29.07%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1595.48, Сделок: 48635, Шарп: 0.02, Просадка: 85.58%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1933.54, Сделок: 48989, Шарп: 0.17, Просадка: 13.66%
# --------------------------------------------------
#
# Сравнение для Transaction Cost (bps)=0.5, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 1334.54, Сделок: 24924, Шарп: 0.03, Просадка: 74.79%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 109.55, Сделок: 24575, Шарп: 0.02, Просадка: 110.90%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1546.44, Сделок: 24651, Шарп: 0.03, Просадка: 42.67%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 963.12, Сделок: 24640, Шарп: 0.05, Просадка: 27.13%
# --------------------------------------------------
#
# Сравнение для Transaction Cost (bps)=1.0, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 105.67, Сделок: 24817, Шарп: 0.03, Просадка: 107.33%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 874.76, Сделок: 24928, Шарп: 0.02, Просадка: 50.34%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1026.21, Сделок: 24732, Шарп: 0.04, Просадка: 46.04%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1257.21, Сделок: 24742, Шарп: 0.02, Просадка: 69.50%
# --------------------------------------------------
#
# Сравнение для Transaction Cost (bps)=2.0, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 635.65, Сделок: 25003, Шарп: 0.01, Просадка: 118.44%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 403.04, Сделок: 24778, Шарп: -0.00, Просадка: 149.14%
# Стратегия: Fixed Spread Benchmark
#   PnL: 753.73, Сделок: 24890, Шарп: 0.02, Просадка: 64.00%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 558.23, Сделок: 24874, Шарп: 0.02, Просадка: 75.12%
# --------------------------------------------------
#
# Сравнение для Tick Size=0.01, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 701.13, Сделок: 24871, Шарп: 0.09, Просадка: 32.66%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 197.40, Сделок: 24787, Шарп: 0.02, Просадка: 110.82%
# Стратегия: Fixed Spread Benchmark
#   PnL: 603.19, Сделок: 24734, Шарп: 0.05, Просадка: 28.75%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 601.59, Сделок: 24409, Шарп: 0.02, Просадка: 64.78%
# --------------------------------------------------
#
# Сравнение для Tick Size=0.05, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 323.46, Сделок: 25281, Шарп: 0.01, Просадка: 40.38%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 374.62, Сделок: 25205, Шарп: 0.02, Просадка: 58.01%
# Стратегия: Fixed Spread Benchmark
#   PnL: 1097.64, Сделок: 24756, Шарп: 0.05, Просадка: 63.37%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 1265.32, Сделок: 24680, Шарп: 0.06, Просадка: 51.10%
# --------------------------------------------------
#
# Сравнение для Tick Size=0.1, волатильность: High
# --------------------------------------------------
# Стратегия: Avellaneda-Stoikov
#   PnL: 1238.01, Сделок: 24666, Шарп: 0.08, Просадка: 33.00%
# Стратегия: Avellaneda-Stoikov Dynamic Decay
#   PnL: 34.36, Сделок: 24457, Шарп: 0.03, Просадка: 113.57%
# Стратегия: Fixed Spread Benchmark
#   PnL: 957.16, Сделок: 24234, Шарп: 0.06, Просадка: 31.92%
# Стратегия: Fixed Spread Benchmark Dynamic Decay
#   PnL: 983.13, Сделок: 24991, Шарп: 0.02, Просадка: 54.60%
# --------------------------------------------------
# Сохранение результатов анализа в plots/BTC-USD_analysis_summary.csv
# Результаты анализа: 104 записей
# Суммарный PnL для синтетических данных: 79769.12
# Общее количество сделок: 2614416
# Создание графика: Final PnL vs Latency
# Создание графика: sharpe_ratio vs Latency
# Создание графика: max_drawdown vs Latency
# Создание графика: Final PnL vs Execution Probability
# Создание графика: sharpe_ratio vs Execution Probability
# Создание графика: max_drawdown vs Execution Probability
# Создание графика: Final PnL vs Transaction Cost (bps)
# Создание графика: sharpe_ratio vs Transaction Cost (bps)
# Создание графика: max_drawdown vs Transaction Cost (bps)
# Создание графика: Final PnL vs Tick Size
# Создание графика: sharpe_ratio vs Tick Size
# Создание графика: max_drawdown vs Tick Size
# Анализ завершен успешно.
# Общий суммарный PnL по всем тестам: 79769.12
# Общее количество сделок по всем тестам: 2614416
